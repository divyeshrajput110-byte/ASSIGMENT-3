# %% [markdown]
# 1. Write a formula to check if the marks in cell b2 are greater than or equal to 40. If yes, return pass, otherwise return fail
#
#
# ans :   ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2. A company gives a bonus  if sales are above 40,000 and attendance is greater than or equal to 90%. Write a
# formula to calculate whether the employee will get a bonus or not .
#
#
# ans:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Write a nested IF formula:
# If marks in are ≥ 90 → , ≥ 75 → , ≥ 50 → , otherwise . B2 "A" "B" "C" "Fail
#
# ans
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Find the Department of Employee ID = E103. Also explain which LOOKUP function is used and why?
#
# ans
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# A company has set the following commission structure for its sales team:
#
# ANS
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# he HR department maintains the following leave records of employees:onus or not .
#
# ANS:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Find the salary of EmpID = E105 using INDEX-MATCH Function.
#
# ANS
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#  se the XLOOKUP function to find the Department of the employee with Emp ID = E303.
#
#  ANS
